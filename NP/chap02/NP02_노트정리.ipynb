# %%
base = 3
height = 2

area = 0.5 * base * height
print("The area of the triangle is:", area)
# Out:
# The area of the triangle is: 3.0

# %%
base = 5
top = 3
height = 2
area = 0.5 * (base + top) * height
print("The area of the trapezoid is:", area)
# Out:
# The area of the trapezoid is: 8.0

# %%
i = 10
j = 5
i, j = j, i
print("i:", i)
print("j:", j)
j = i + j
print("j:", j)
# Out:
# i: 5
# j: 10
# j: 15
